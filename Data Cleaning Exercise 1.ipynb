# %% [markdown]
# # Data Cleaning Excercise
#
# ## Task:
#
# Have a look at the following dataset: dsm-beuth-edl-demodata-orig
#
# Write a Python / Panda Script which 'cleans' this data set. Justify your actions in the respective notebook or python script you provide as a solution (link, file, kaggle repo, etc.).
#
# The original dataset does not necessarily have to be created. A proper strategy / good arguments are more important. Value: 5 points.
#
# ## Solution

# %%
import pandas as pd
import numpy as np

url = "https://raw.githubusercontent.com/edlich/eternalrepo/master/DS-WAHLFACH/dsm-beuth-edl-demodata-dirty.csv"
demodata = pd.read_csv(url)

# %% [markdown]
# ### 1. Asses data (dimensions, types etc.)

# %%
demodata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          20 non-null     float64
#  1   full_name   21 non-null     object
#  2   first_name  21 non-null     object
#  3   last_name   21 non-null     object
#  4   email       20 non-null     object
#  5   gender      20 non-null     object
#  6   age         21 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 1.4+ KB

# %%
demodata.head(22)
# Out:
#       id              full_name  first_name    last_name  \
# 0    1.0        Mariel Finnigan      Mariel     Finnigan
# 1    2.0          Kenyon Possek      Kenyon       Possek
# 2    3.0         Lalo Manifould        Lalo    Manifould
# 3    4.0         Nickola Carous     Nickola       Carous
# 4    5.0          Norman Dubbin      Norman       Dubbin
# 5    6.0           Hasty Perdue       Hasty       Perdue
# 6    7.0         Franz Castello       Franz     Castello
# 7    8.0           Jorge Tarney       Jorge       Tarney
# 8    9.0     Eunice Blakebrough      Eunice  Blakebrough
# 9   10.0  Kristopher Frankcombe  Kristopher   Frankcombe
# 10  11.0           Palm Domotor        Palm      Domotor
# 11  12.0          Luz Lansdowne         Luz    Lansdowne
# 12  13.0         Modestia Keble    Modestia        Keble
# 13  14.0           Stacee Bovis      Stacee        Bovis
# 14  15.0              Eden Wace        Eden         Wace
# 15  16.0              Eden Wace        Eden         Wace
# 16  17.0        Tobias Sherburn      Tobias     Sherburn
# 17   NaN                    NaN         NaN          NaN
# 18  19.0         Clair Skillern       Clair     Skillern
# 19  20.0        Mathew Addicott      Mathew     Addicott
# 20  21.0       Kerianne Goacher    Kerianne      Goacher
# 21   NaN          Maurits Shawl     Maurits        Shawl
#
#                              email  gender  age
# 0              mfinnigan0@usda.gov  Female   60
# 1                kpossek1@ucoz.com    Male   12
# 2              lmanifould2@pbs.org    Male   26
# 3                ncarous3@phoca.cz    Male    4
# 4           ndubbin4@wikipedia.org    Male   17
# 5                  hperdue5@qq.com     NaN   77
# 6              fcastello6@1688.com    Male   25
# 7                  jtarney7@ft.com    Male   77
# 8           eblakebrough8@sohu.com  Female   45
# 9           kfrankcombe9@slate.com    Male  old
# 10             pdomotora@github.io    Male    6
# 11     llansdowneb@theguardian.com  Female   16
# 12                 mkeblec@cmu.edu  Female   91
# 13           sbovisd@webeden.co.uk  Female   22
# 14             ewacee@marriott.com  Female   16
# 15             ewacee@marriott.com  Female   16
# 16         tsherburnf@facebook.com    Male    2
# 17                             NaN     NaN  NaN
# 18              cskillerng@nih.gov    Male  -78
# 19  maddicotth@acquirethisname.com    Male   65
# 20                             NaN  Female   45
# 21                mshawlj@dmoz.org    Male   72

# %% [markdown]
# ### 2. Drop all-NaN rows

# %%
demodata.dropna(axis=0, how='all', inplace=True)

# %% [markdown]
# ### 3. Drop dublicate rows

# %%
demodata.drop_duplicates(subset=demodata.columns.difference(['id']), keep='first', inplace=True, ignore_index=True)

# %% [markdown]
# ### 4. Replace NaN fields in the gender and email column with apropriate values

# %%
demodata.gender = demodata.gender.fillna("unknown")
demodata.email = demodata.email.fillna("none")

# %% [markdown]
# ### 5. Fix the id column (float to int and conscutive numbering)

# %%
demodata["id"] = np.arange(demodata.shape[0])

# %% [markdown]
# ### 6. Replace "old" with "99" and convert age column from objact to positive integer

# %%
demodata["age"].replace({"old": "99"}, inplace=True)
demodata['age'] = demodata['age'].astype(int)
demodata['age'] = demodata['age'].abs()

# %% [markdown]
# ### 7. Print result

# %%
demodata.head(22)
# no need to write csv
# demodata.to_csv("dsm-beuth-edl-demodata-cleaned.csv")
# Out:
#     id              full_name  first_name    last_name  \
# 0    0        Mariel Finnigan      Mariel     Finnigan
# 1    1          Kenyon Possek      Kenyon       Possek
# 2    2         Lalo Manifould        Lalo    Manifould
# 3    3         Nickola Carous     Nickola       Carous
# 4    4          Norman Dubbin      Norman       Dubbin
# 5    5           Hasty Perdue       Hasty       Perdue
# 6    6         Franz Castello       Franz     Castello
# 7    7           Jorge Tarney       Jorge       Tarney
# 8    8     Eunice Blakebrough      Eunice  Blakebrough
# 9    9  Kristopher Frankcombe  Kristopher   Frankcombe
# 10  10           Palm Domotor        Palm      Domotor
# 11  11          Luz Lansdowne         Luz    Lansdowne
# 12  12         Modestia Keble    Modestia        Keble
# 13  13           Stacee Bovis      Stacee        Bovis
# 14  14              Eden Wace        Eden         Wace
# 15  15        Tobias Sherburn      Tobias     Sherburn
# 16  16         Clair Skillern       Clair     Skillern
# 17  17        Mathew Addicott      Mathew     Addicott
# 18  18       Kerianne Goacher    Kerianne      Goacher
# 19  19          Maurits Shawl     Maurits        Shawl
#
#                              email   gender  age
# 0              mfinnigan0@usda.gov   Female   60
# 1                kpossek1@ucoz.com     Male   12
# 2              lmanifould2@pbs.org     Male   26
# 3                ncarous3@phoca.cz     Male    4
# 4           ndubbin4@wikipedia.org     Male   17
# 5                  hperdue5@qq.com  unknown   77
# 6              fcastello6@1688.com     Male   25
# 7                  jtarney7@ft.com     Male   77
# 8           eblakebrough8@sohu.com   Female   45
# 9           kfrankcombe9@slate.com     Male   99
# 10             pdomotora@github.io     Male    6
# 11     llansdowneb@theguardian.com   Female   16
# 12                 mkeblec@cmu.edu   Female   91
# 13           sbovisd@webeden.co.uk   Female   22
# 14             ewacee@marriott.com   Female   16
# 15         tsherburnf@facebook.com     Male    2
# 16              cskillerng@nih.gov     Male   78
# 17  maddicotth@acquirethisname.com     Male   65
# 18                            none   Female   45
# 19                mshawlj@dmoz.org     Male   72
